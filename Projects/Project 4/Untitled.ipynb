# %%
import pandas as pd
df = pd.read_csv('prepdata.csv')
df.sample(5)
# Out:
#                NAME  PERCENTAGE  BACKLOG  INTERNSHIP  FIRSTROUND  \
# 157    Pradeep Shah          89        0           1          87
# 10         Jigyasha          56        4           2          78
# 132  Vaibhav Sharma          80        2           1          77
# 57            Monty          77        1           2          73
# 282              Sg          68        0           3          92
#
#      COMMUNICATIONSKILLLS  Hired
# 157                    84      1
# 10                     60      0
# 132                    80      1
# 57                     60      0
# 282                    45      1

# %%
X = df[['PERCENTAGE','BACKLOG','INTERNSHIP','FIRSTROUND','COMMUNICATIONSKILLLS']]
Y = df[['Hired']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.25,random_state=26)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = model.predict(x_test)

# %%
import seaborn as sb
import matplotlib.pyplot as py
sb.distplot(y_test-predictions)
py.show()

# %%
import numpy as np
myvals = np.array([45,3,1,66,45]).reshape(1,-1)
print(myvals)
# Out:
# [[45  3  1 66 45]]

# %%
model.predict(myvals)
# Out:
# array([[-0.04947576]])
