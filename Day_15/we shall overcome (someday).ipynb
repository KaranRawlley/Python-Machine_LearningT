# %%
import cv2 #cv2.imread() used to read an image(first argument : path of image,second argument : 1 for color; 0 for grayscale;-1 for B/W)
import numpy as np
img = cv2.imread('sample-images/sample-images/news.jpg',0)
print(img)
# Out:
# [[221 221 222 ..., 229 229 229]
#  [221 221 222 ..., 229 229 229]
#  [221 221 222 ..., 229 229 229]
#  ...,
#  [ 75  72  73 ...,   0   0   0]
#  [ 77  72  80 ...,   0   0   0]
#  [ 77  73  81 ...,   0   0   0]]

# %%
# fn to display an image using cv2.imshow('image',img)  
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# cv2.namedWindow() is used to autosize or normal *(arguments 1: 'image',2: cv2.WINDOW_AUTOSIZE(Default) or cv2.WINDOW_NORMAL )
cv2.namedWindow('image',cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# create a copy of image with given name & extention  cv2.imwrite() 
cv2.imwrite('bpit.png',img)

# %%
## getting keys from cv2.waitKey(0)

import numpy as np
import cv2
img = cv2.imread('sample-images/sample-images/news.jpg',0)
cv2.imshow('Nishant',img)
k = cv2.waitKey(0)
print(k)
if k==27:# key value of 'escape' key
    cv2.destroyAllWindows()
elif k==ord('s'): #if pressed key is 's'
    cv2.imwrite('news_12233.png',img)
    cv2.destroyAllWindows()
# Out:
# 115

# %%
# use of cv2.resize() to resize an image
'''
print(img.shape)
print(img.size)
print(img.dtype)
print(type(img))
print(img.ndim)'''
# res = cv2.resize(img,(800,1275))
# print(res.shape)
res2=cv2.resize(img,(int(img.shape[1]/10),int(img.shape[0]/10)))
cv2.imshow('image_res',res2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Capturing Video

# %%
# import cv2,time

# video  = cv2.VideoCapture(0) # function to capture video
# while True:
    
#     check,frame = video.read()
# #     print(check)
# #     print(frame)
#     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# #     time.sleep(3)
    
#     cv2.imshow('Capturing',gray)
#     k = cv2.waitKey(1)
#     if k==ord('q'):
#         break
# video.release()       
# cv2.destroyAllWindows()

import cv2,time
video=cv2.VideoCapture(0)
while True:
    check,frame=video.read()
    cv2.imshow('Capturing',frame)
    k=cv2.waitKey(1)
    if k==ord('q'):
        break
video.release()
cv2.destroyAllWindows()

# %%
video.release()
cv2.destroyAllWindows()

# %%
# video writer
# import cv2

# cap  = cv2.VideoCapture(0)
# fourcc = cv2.Videowriter_fourcc(*'MJPG')
# out = cv2.VideoWriter('outpur.avi',fourcc,5.0,(640,480))
# while True:
#     ret,frame=cap.read()
#     gray=cv2cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     out.write(frame)
#     cv2.imshow('frame',gray)
#     if(cv2.waitKey(1)&0xFF==ord('q')):
#         break
        
# cap.release()
# out.release()
# cv2.destroyAllWindows()

# %%
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
print('Hola')

# %%
#face detection
import numpy as np
import cv2
#mutiple cascades : https://github.com/Itseez/opencv/tree....
face_cascade = cv2.CascadeClassifier('sample-images/sample-images/haarcascade_frontalface_default.xml')
img =cv2.imread('images.jpg',1)

gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray,scaleFactor=1.3,minNeighbors=5)

print(faces)

for(x,y,w,h) in faces:
    cv2.rectagle(img,(x,y),(x+w,y+h)(255,0,0),2)
    rg = gray[y:y+h,x:x+w]
    rc = img[y:y+h,x:x+w]
    
cv2.imshow('img',img)
cv2.imshow('img1',rg)
cv2.imshow('img2',rc)
cv2.wait_key(0)
cv2.destroyAllWindows()

# %%
import pyhook
